# %%
user = AdditionalUserInfo.objects.get(name="cto")
print(user.get_depth())
# Out:
# here
# neogelon@gmail.com
# True
# domisavio@gdca.or.kr
# False
# 2

# %%
from django.contrib.auth.models import User
import datetime
u = User.objects.get(username='gca_manager@test.com')
today_min = datetime.datetime.now()
sp = SupportBusiness.objects.all().filter(open_status=True).filter(apply_end__gt=today_min).filter(apply_start__lt=today_min)
print(sp)
# Out:
# <QuerySet [<SupportBusiness: <서부경기문화창조허브 기술장인 및 참가기업> 모집공고>, <SupportBusiness: 2018년 빅스타 선발대회>, <SupportBusiness: 해외진출 IP-법률컨설팅 지원사업>, <SupportBusiness: MDC 공동창작 프로젝트>, <SupportBusiness: 도쿄게임쇼 2018>, <SupportBusiness: 게임스컴 2018>]>

# %%
user = AdditionalUserInfo.objects.get(id=4)
print(user)
print(user.child_list())

# %%
import inspect 
inspect.getmembers(user)
print((user.additionaluserinfo_set.all()[0]))

# %%
#. case1. 3개 항목 모두가 필터 인경우
s = Startup.objects.all().filter(filter__name="1인제조업").filter(filter__name="AR").filter(filter__name="경기도기업")
print(s)


# case2.  영역-1인 기업의 기본장르-출판 별 -*선정자수*- 

# 1. 타이틀에 위치한 스타트업 항목을 추출
s = Startup.objects.all().filter(filter__name="1인제조업")

# 기본장르-출판별 추출
s = s.filter(filter__name="출판")

# 선정자수  => 각 사업 종류별 선정자수 나열
sb_kind_list = Filter.objects.all().filter(cat_0="지원형태").values('cat_1').distinct() # => 사업 종류 추출
print(sb_kind_list)

for kind in sb_kind_list :
    num_of_selected=[]
    print(kind)
    for sb in SupportBusiness.object.all().filter(filter__cat_1=kind):
        num_of_selected[kind] = len(Award.objects.all().filter(sb=SupportBusiness.object.get(filter__cat_1=kind)))

# %%
for sp in SupportBusiness.objects.all():
    sp.confirm_list.add(sp.user)

# %%
for sp in SupportBusiness.objects.all():
    obj = {}
    obj["tag"] =[]
    obj["title"] = sp.title
    obj["due"] = sp.apply_end
    obj["title_sub"]=sp.title_sub
    obj["short_desc"]=sp.short_desc
    obj["int"]= (sp.additionaluserinfo_set.all())
    for f in sp.filter.all():
        obj["tag"].append(f.name)
    print(obj)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\mysql\base.py in execute(self, query, args)
#     100             # args is None means no string interpolation
# --> 101             return self.cursor.execute(query, args)
#     102         except Database.OperationalError as e:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
#     251         self._executed = query
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in defaulterrorhandler(***failed resolving arguments***)
#      49     if isinstance(errorvalue, BaseException):
# ---> 50         raise errorvalue
#      51     if errorclass is not None:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     246         try:
# --> 247             res = self._query(query)
#     248         except Exception:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     410     def _query(self, q):
# --> 411         rowcount = self._do_query(q)
#     412         self._post_get_result()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _do_query(self, q)
#     373         self._last_executed = q
# --> 374         db.query(q)
#     375         self._do_get_result()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     276         else:
# --> 277             _mysql.connection.query(self, query)
#     278
#
# OperationalError: (1054, "Unknown column 'supporting_business_additionaluserinfo.boss_id' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-99257b649b03> in <module>()
#       9     for f in sp.filter.all():
#      10         obj["tag"].append(f.name)
# ---> 11     print(obj)
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in __repr__(self)
#     224
#     225     def __repr__(self):
# --> 226         data = list(self[:REPR_OUTPUT_SIZE + 1])
#     227         if len(data) > REPR_OUTPUT_SIZE:
#     228             data[-1] = "...(remaining elements truncated)..."
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in __iter__(self)
#     248                - Responsible for turning the rows into model objects.
#     249         """
# --> 250         self._fetch_all()
#     251         return iter(self._result_cache)
#     252
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in _fetch_all(self)
#    1100     def _fetch_all(self):
#    1101         if self._result_cache is None:
# -> 1102             self._result_cache = list(self._iterable_class(self))
#    1103         if self._prefetch_related_lookups and not self._prefetch_done:
#    1104             self._prefetch_related_objects()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in __iter__(self)
#      51         # Execute the query. This will also fill compiler.select, klass_info,
#      52         # and annotations.
# ---> 53         results = compiler.execute_sql(chunked_fetch=self.chunked_fetch)
#      54         select, klass_info, annotation_col_map = (compiler.select, compiler.klass_info,
#      55                                                   compiler.annotation_col_map)
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\sql\compiler.py in execute_sql(self, result_type, chunked_fetch)
#     874             cursor = self.connection.cursor()
#     875         try:
# --> 876             cursor.execute(sql, params)
#     877         except Exception:
#     878             try:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      78         start = time()
#      79         try:
# ---> 80             return super(CursorDebugWrapper, self).execute(sql, params)
#      81         finally:
#      82             stop = time()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\utils.py in __exit__(self, exc_type, exc_value, traceback)
#      92                 if dj_exc_type not in (DataError, IntegrityError):
#      93                     self.wrapper.errors_occurred = True
# ---> 94                 six.reraise(dj_exc_type, dj_exc_value, traceback)
#      95
#      96     def __call__(self, func):
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\utils\six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\mysql\base.py in execute(self, query, args)
#      99         try:
#     100             # args is None means no string interpolation
# --> 101             return self.cursor.execute(query, args)
#     102         except Database.OperationalError as e:
#     103             # Map some error codes to IntegrityError, since they seem to be
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     248         except Exception:
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
#     251         self._executed = query
#     252         if not self._defer_warnings:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in defaulterrorhandler(***failed resolving arguments***)
#      48     del connection
#      49     if isinstance(errorvalue, BaseException):
# ---> 50         raise errorvalue
#      51     if errorclass is not None:
#      52         raise errorclass(errorvalue)
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     245         res = None
#     246         try:
# --> 247             res = self._query(query)
#     248         except Exception:
#     249             exc, value = sys.exc_info()[:2]
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     409
#     410     def _query(self, q):
# --> 411         rowcount = self._do_query(q)
#     412         self._post_get_result()
#     413         return rowcount
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _do_query(self, q)
#     372         db = self._get_db()
#     373         self._last_executed = q
# --> 374         db.query(q)
#     375         self._do_get_result()
#     376         return self.rowcount
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     275             self.read_query_result()
#     276         else:
# --> 277             _mysql.connection.query(self, query)
#     278
#     279     def __enter__(self):
#
# OperationalError: (1054, "Unknown column 'supporting_business_additionaluserinfo.boss_id' in 'field list'")

# %%
id = 230
sp = SupportBusiness.objects.all().get(id=id)
result = {}
result["title"] = sp.title
result["apply_start"] = sp.apply_start
result["apply_end"] = sp.apply_end
result["object"] = sp.object
result["top_support_tag"]=[]
for t in sp.filter.all():
    print(t)
    
print(sp.user)
# Out:
# 영역/창업/스타트업
# 영역/IT 관련/ICT
# 조건/업력/7년 이내
# 지원형태/엑셀러레이팅 투자연계/엑셀러레이팅 프로그램
# 지원형태/판로/해외 진출 지원
# 지원형태/네트워킹/전문가 컨설팅&멘토링
# 지원형태/피칭/기업피칭
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\fields\related_descriptors.py in __get__(self, instance, cls)
#     177         try:
# --> 178             rel_obj = getattr(instance, self.cache_name)
#     179         except AttributeError:
#
# AttributeError: 'SupportBusiness' object has no attribute '_user_cache'
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\mysql\base.py in execute(self, query, args)
#     100             # args is None means no string interpolation
# --> 101             return self.cursor.execute(query, args)
#     102         except Database.OperationalError as e:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
#     251         self._executed = query
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in defaulterrorhandler(***failed resolving arguments***)
#      49     if isinstance(errorvalue, BaseException):
# ---> 50         raise errorvalue
#      51     if errorclass is not None:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     246         try:
# --> 247             res = self._query(query)
#     248         except Exception:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     410     def _query(self, q):
# --> 411         rowcount = self._do_query(q)
#     412         self._post_get_result()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _do_query(self, q)
#     373         self._last_executed = q
# --> 374         db.query(q)
#     375         self._do_get_result()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     276         else:
# --> 277             _mysql.connection.query(self, query)
#     278
#
# OperationalError: (1054, "Unknown column 'supporting_business_additionaluserinfo.boss_id' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-26-5eaa9e202ea8> in <module>()
#      10     print(t)
#      11
# ---> 12 print(sp.user)
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\fields\related_descriptors.py in __get__(self, instance, cls)
#     182                 rel_obj = None
#     183             else:
# --> 184                 rel_obj = self.get_object(instance)
#     185                 # If this is a one-to-one relation, set the reverse accessor
#     186                 # cache on the related object to the current instance to avoid
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\fields\related_descriptors.py in get_object(self, instance)
#     157         qs = self.get_queryset(instance=instance)
#     158         # Assuming the database enforces foreign keys, this won't fail.
# --> 159         return qs.get(self.field.get_reverse_related_filter(instance))
#     160
#     161     def __get__(self, instance, cls=None):
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in get(self, *args, **kwargs)
#     371         if self.query.can_filter() and not self.query.distinct_fields:
#     372             clone = clone.order_by()
# --> 373         num = len(clone)
#     374         if num == 1:
#     375             return clone._result_cache[0]
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in __len__(self)
#     230
#     231     def __len__(self):
# --> 232         self._fetch_all()
#     233         return len(self._result_cache)
#     234
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in _fetch_all(self)
#    1100     def _fetch_all(self):
#    1101         if self._result_cache is None:
# -> 1102             self._result_cache = list(self._iterable_class(self))
#    1103         if self._prefetch_related_lookups and not self._prefetch_done:
#    1104             self._prefetch_related_objects()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\query.py in __iter__(self)
#      51         # Execute the query. This will also fill compiler.select, klass_info,
#      52         # and annotations.
# ---> 53         results = compiler.execute_sql(chunked_fetch=self.chunked_fetch)
#      54         select, klass_info, annotation_col_map = (compiler.select, compiler.klass_info,
#      55                                                   compiler.annotation_col_map)
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\models\sql\compiler.py in execute_sql(self, result_type, chunked_fetch)
#     874             cursor = self.connection.cursor()
#     875         try:
# --> 876             cursor.execute(sql, params)
#     877         except Exception:
#     878             try:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      78         start = time()
#      79         try:
# ---> 80             return super(CursorDebugWrapper, self).execute(sql, params)
#      81         finally:
#      82             stop = time()
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\utils.py in __exit__(self, exc_type, exc_value, traceback)
#      92                 if dj_exc_type not in (DataError, IntegrityError):
#      93                     self.wrapper.errors_occurred = True
# ---> 94                 six.reraise(dj_exc_type, dj_exc_value, traceback)
#      95
#      96     def __call__(self, func):
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\utils\six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# ~\PycharmProjects\gca_venv\lib\site-packages\django\db\backends\mysql\base.py in execute(self, query, args)
#      99         try:
#     100             # args is None means no string interpolation
# --> 101             return self.cursor.execute(query, args)
#     102         except Database.OperationalError as e:
#     103             # Map some error codes to IntegrityError, since they seem to be
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     248         except Exception:
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
#     251         self._executed = query
#     252         if not self._defer_warnings:
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in defaulterrorhandler(***failed resolving arguments***)
#      48     del connection
#      49     if isinstance(errorvalue, BaseException):
# ---> 50         raise errorvalue
#      51     if errorclass is not None:
#      52         raise errorclass(errorvalue)
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     245         res = None
#     246         try:
# --> 247             res = self._query(query)
#     248         except Exception:
#     249             exc, value = sys.exc_info()[:2]
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     409
#     410     def _query(self, q):
# --> 411         rowcount = self._do_query(q)
#     412         self._post_get_result()
#     413         return rowcount
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\cursors.py in _do_query(self, q)
#     372         db = self._get_db()
#     373         self._last_executed = q
# --> 374         db.query(q)
#     375         self._do_get_result()
#     376         return self.rowcount
#
# ~\PycharmProjects\gca_venv\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     275             self.read_query_result()
#     276         else:
# --> 277             _mysql.connection.query(self, query)
#     278
#     279     def __enter__(self):
#
# OperationalError: (1054, "Unknown column 'supporting_business_additionaluserinfo.boss_id' in 'field list'")
