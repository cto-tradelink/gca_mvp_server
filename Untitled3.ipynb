# %%
for s in SupportBusiness.objects.all():
    print(s.support_business_poster.replace("poster","poster2"))
# Out:
# None
# None
# None
# None
# media/uploads/poster/2018_「2018년 지역산업맞춤형 청년창업 SMART2030 일자리창출 지원사업」_해님1 컴퍼니_해님1 (1)2018_「2018년 지역산업맞춤형 청년창업 SMART2030 일자리창출 지원사업」_해님1 컴퍼니_해님1 .png
# media/uploads/poster/1 (1).jpg
# None
# None
# media/uploads/poster/1.jpg
# media/uploads/poster/1 (1).jpg
# media/uploads/poster/1 (1).jpg
# media/uploads/poster/ssinhon.png
# media/uploads/poster/1 (1).jpg
# media/uploads/poster/1 (1).jpg
# None
# None
# None
# media/uploads/poster/c_mainimg.jpg
# media/uploads/poster/애.jpg
# media/uploads/poster/1_G-시네인센티브지원사업_포스터_최종본-e1526372355675.png
# media/uploads/poster/powow2.png
# media/uploads/poster/97487465-rocket-icon-start-up-business-concept.jpg
# media/uploads/poster/라이선싱엑스포포스터.PNG
# media/uploads/poster/라이선싱엑스포포스터.PNG
# media/uploads/poster/라이선싱엑스포포스터.PNG

# %%
for a in Alarm.objects.all():
    a.alarm_read=True
    a.save()
    print(a)
# Out:
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# Alarm object
# ...
